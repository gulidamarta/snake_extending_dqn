# %%
# !pip install torch torchvision torchaudio
# !pip install gymnasium==0.29.1
# !pip install minatar==1.0.15
# !pip install matplotlib
# !pip install imageio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting gymnasium==0.29.1
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.29.1) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.29.1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.29.1) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.29.1)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Collecting minatar==1.0.15
#   Downloading MinAtar-1.0.15-py3-none-any.whl (16 kB)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (1.4.5)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (3.7.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (1.5.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (2023.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (1.11.4)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (0.13.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from minatar==1.0.15) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->minatar==1.0.15) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->minatar==1.0.15) (4.47.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->minatar==1.0.15) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.3->minatar==1.0.15) (9.4.0)
# Installing collected packages: minatar
# Successfully installed minatar-1.0.15
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)

# %%
# Imports
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import copy
import numpy as np
import pandas as pd
import random
from PIL import Image
import gymnasium as gym
import matplotlib.pyplot as plt
from typing import Callable
from collections import namedtuple
import itertools

# %%
torch.cuda.is_available()
# Out:
# False

# %%
class DQN(nn.Module):
    def __init__(self, obs_shape: torch.Size, num_actions: int):
        """
        Initialize the DQN network.

        :param obs_shape: Shape of the observation space
        :param num_actions: Number of actions
        """

        # obs_shape is the shape of a single observation -> use this information to define the dimensions of the layers
        super(DQN, self).__init__()

        # TODO: your code
        self.conv1 = nn.Conv2d(obs_shape[-1], 16, stride=1, kernel_size=5)
        self.conv2 = nn.Conv2d(16, 32, stride=1, kernel_size=3)

        self.fc1 = nn.Linear(32 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, num_actions)

        self.relu = nn.ReLU()


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # TODO: your code
        x = x.permute(0, 3, 1, 2)

        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))

        x = torch.flatten(x, 1) # flatten the intermediate result such that it can serve as input for the first linear layer

        # Final layer consists of 128 "rectifier" units meaning a ReLU activation
        # As several students have not understood it this way, no points are deducted for missing the last activation
        x = self.relu(self.fc1(x))
        out = self.fc2(x)
        return out

# %%
def make_epsilon_greedy_policy(Q: nn.Module, num_actions: int):
    """
    Creates an epsilon-greedy policy based on a given Q-function and epsilon.

    :param Q: The DQN network.
    :param num_actions: Number of actions in the environment.

    :returns: A function that takes the observation as an argument and returns the greedy action in form of an int.
    """

    def policy_fn(obs: torch.Tensor, epsilon: float = 0.0):
        """This function takes in the observation and returns an action."""
        if np.random.uniform() < epsilon:
            return np.random.randint(0, num_actions)

        # For action selection, we do not need a gradient and so we call ".detach()"
        return Q(obs).argmax().detach().numpy()

    return policy_fn

# %%
def linear_epsilon_decay(eps_start: float, eps_end: float, current_timestep: int, duration: int) -> float:
    """
    Linear decay of epsilon.

    :param eps_start: The initial epsilon value.
    :param eps_end: The final epsilon value.
    :param current_timestep: The current timestep.
    :param duration: The duration of the schedule (in timesteps). So when schedule_duration == current_timestep, eps_end should be reached

    :returns: The current epsilon.
    """

    # TODO: your code
    ratio = min(1.0, current_timestep / duration)
    return (eps_start - eps_end) * (1 - ratio) + eps_end

# %%
import matplotlib.pyplot as plt

eps_start = 1.0
eps_end = 0.2
schedule_duration = 1000

eps_values = [linear_epsilon_decay(eps_start, eps_end, t, 600) for t in range(schedule_duration)]

plt.plot(range(schedule_duration), eps_values)
plt.xlabel('Time Step')
plt.ylabel('Epsilon')
plt.title('Linear Epsilon Decay')
plt.show()

# %%
test_input = torch.tensor([1, 2, 3, 4], dtype=torch.float32)

# Given a neural network
net = nn.Sequential(
    nn.Linear(4, 3),
    nn.ReLU(),
    nn.Linear(3, 1)
)
print(f"Prediction (Before): {net(test_input)}\n")

# We can get its parameters with .state_dict(). A dictionary containing all the parameters.
# Note: It contains even more than parameters, but that is not relevant for us.
params = copy.deepcopy(net.state_dict())

print("Parameters:")
for key, value in params.items():
    print(f"- Parameter {key}:\n{value}")

# Set weight matrix of first layer to zero
net[0].weight.data.fill_(0.0)
print(f"\nPrediction (After change): {net(test_input)}\n")

# Load the old parameters
net.load_state_dict(params)
print(f"Prediction (After reload): {net(test_input)}\n")
# Out:
# Prediction (Before): tensor([-0.0401], grad_fn=<ViewBackward0>)
#
# Parameters:
# - Parameter 0.weight:
# tensor([[ 0.2438, -0.4854, -0.0551,  0.2638],
#         [ 0.2915,  0.0903,  0.2398, -0.4328],
#         [-0.1518,  0.1586,  0.4480,  0.2721]])
# - Parameter 0.bias:
# tensor([ 0.0309, -0.3131,  0.3174])
# - Parameter 2.weight:
# tensor([[-0.0868, -0.3314, -0.0445]])
# - Parameter 2.bias:
# tensor([0.1064])
#
# Prediction (After change): tensor([0.0896], grad_fn=<ViewBackward0>)
#
# Prediction (After reload): tensor([-0.0401], grad_fn=<ViewBackward0>)

# %%
from collections import deque

class PrioritizedReplayBuffer:
    def __init__(self, max_size: int):
        """
        Create the replay buffer.

        :param max_size: Maximum number of transitions in the buffer.
        """
        self.max_size = max_size
        self.data = deque(maxlen=max_size)
        self.priorities = deque(maxlen=max_size)
        self.position = 0
        self.max_priority = 1

    def __len__(self) -> int:
        """Returns how many transitions are currently in the buffer."""
        return len(self.data)

    def get_probabilities(self, alpha):
        # Probability(i) = (priority(i)^alpha)/(Sum(priority(i)^alpha))
        # Priority could have approximation errors, so to address this we use alpha;
        # alpha=0.0 becomes Pure Random sampling
        # alpha=1.0 becomes Pure prioritized random sampling

        priorities_tensor = torch.tensor(self.priorities) #, dtype=torch.float32) #lesser precision for faster calculation
        scaled_priorities = torch.pow(priorities_tensor, alpha)
        probabilities = scaled_priorities / torch.sum(scaled_priorities)


        #print(f"type(self.priorities)={type(self.priorities)}, type(self.priorities[0])={type(self.priorities[0])}")
        #print(f"type(self.priorities).dtype={(self.priorities).dtype}, (self.priorities[0]).dtype={(self.priorities[0]).dtype}")
        #print(f"type(priorities_tensor)={type(priorities_tensor)}, type(priorities_tensor[0])={type(priorities_tensor[0])}")
        #print(f"(priorities_tensor).dtype={(priorities_tensor).dtype}, (priorities_tensor[0]).dtype={(priorities_tensor[0]).dtype}")
        return probabilities

    def set_priorities(self, indices, errors, offset=0.05):
        for i, e in zip(indices, errors):
            #print(f"e.dtype={e.dtype}, type(e)={type(e)}")
            self.priorities[i] = abs(e) + offset

    def get_importance(self, probabilities, beta):
        # importance_weight = Corrects the bias introduced by not uniformly sampling during the neural network backward pass
        # importance_weight = ((1/N) * (1/Probability(i))) ^ Beta
        # Beta is a hyperparameter here; which similar to alpha, controls how much we want to prioritize

        N_length = len(self.data)
        importance_weight = (1/N_length) * (1/probabilities)
        scaled_importance_weight = torch.pow(importance_weight, beta)
        max_weight = torch.max(scaled_importance_weight) #To normalize
        return (scaled_importance_weight / max_weight)

    def store(self, obs: torch.Tensor, action: torch.Tensor, reward: torch.Tensor, next_obs: torch.Tensor, terminated: torch.Tensor):
        """
        Adds a new transition to the buffer. When the buffer is full, overwrite the oldest transition.

        :param obs: The current observation.
        :param action: The action.
        :param reward: The reward.
        :param next_obs: The next observation.
        :param terminated: Whether the episode terminated.
        """
        data = (obs, action, reward, next_obs, terminated)
        if len(self.data) < self.max_size:
            self.data.append(data)
            # To optimise computational speed, setting constant higher priority for newer experience
            self.priorities.append(self.max_priority) #(max(self.priorities, default=1))  # Setting initial priorities
        else:
            self.data[self.position] = data
            # To optimise computational speed, setting constant higher priority for newer experience
            self.priorities[self.position] = self.max_priority #max(self.priorities, default=1)  # Setting initial priorities
        self.position = (self.position + 1) % self.max_size

    def sample(self, batch_size: int, alpha=1.0, beta=1.0) -> torch.Tensor:
        """
        Sample a batch of transitions uniformly and with replacement. The respective elements e.g. states, actions, rewards etc. are stacked

        :param batch_size: The batch size.
        :returns: A tuple of tensors (obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch), where each tensors is stacked.
        """

        sample_size = min(len(self.data), batch_size)
        sample_probs = self.get_probabilities(alpha)
        sample_indices = random.choices(range(len(self.data)), k=batch_size, weights=sample_probs)

        selected_samples = [self.data[i] for i in sample_indices]
        output = [torch.stack(b) for b in zip(*selected_samples)]
        importance = self.get_importance(sample_probs[sample_indices], beta)
        return output, sample_indices, importance

# %%
"""
class PrioritizedReplayBuffer:
    def __init__(self, max_size: int):

        #Create the replay buffer.

        #:param max_size: Maximum number of transitions in the buffer.

        self.data = []
        self.priorities = []
        self.max_size = max_size
        self.position = 0

    def __len__(self) -> int:
        # Returns how many transitions are currently in the buffer
        # TODO: Your code
        return len(self.data)

    def get_probabilities(self, alpha):
        # Probability(i) = (priority(i)^alpha)/(Sum(priority(i)^alpha))
        # Priority could have approximation errors, so to address this we use alpha;
        # alpha=0.0 becomes Pure Random sampling
        # alpha=1.0 becomes Pure prioritized random sampling
        scaled_priorities = torch.pow(torch.tensor(self.priorities), alpha) #torch.tensor(self.priorities) ** alpha
        probabilities = scaled_priorities/torch.sum(scaled_priorities)
        return probabilities

    def set_priorities(self, indices, errors, offset=0.05):
        for i, e in zip(indices, errors):
            self.priorities[i] = abs(e) + offset

    def get_importance(self, probabilities, beta):
        # importance_weight = Corrects the bias introduced by not uniformly sampling during the neural network backward pass
        # importance_weight = ((1/N) * (1/Probability(i))) ^ Beta
        # Beta is a hyperparameter here; which similar to alpha, controls how much we want to prioritize
        N_length = len(self.data)
        importance_weight = (1/N_length * 1/probabilities)  #(1/len(self.data) * 1/probabilities) ** beta
        scaled_importance_weight = torch.pow(importance_weight,beta)
        importance_weight_normalized = scaled_importance_weight / torch.max(scaled_importance_weight)
        return importance_weight_normalized

    def store(self, obs: torch.Tensor, action: torch.Tensor, reward: torch.Tensor, next_obs: torch.Tensor, terminated: torch.Tensor):

        #Adds a new transition to the buffer. When the buffer is full, overwrite the oldest transition.

        #:param obs: The current observation.
        #:param action: The action.
        #:param reward: The reward.
        #:param next_obs: The next observation.
        #:param terminated: Whether the episode terminated.

        # TODO: Your code
        data = (obs, action, reward, next_obs, terminated)
        if len(self.data) < self.max_size:
            self.data.append(data)
            self.priorities.append(max(self.priorities, default=1)) #Setting initial priorities
        else:
            self.position = self.position % self.max_size
            self.data[self.position] = data
            self.priorities[self.position] = max(self.priorities, default=1) #Setting initial priorities
        self.position = self.position + 1

    def sample(self, batch_size: int, alpha=1.0, beta=1.0) -> torch.Tensor:

        #Sample a batch of transitions uniformly and with replacement. The respective elements e.g. states, actions, rewards etc. are stacked

        #:param batch_size: The batch size.
        #:returns: A tuple of tensors (obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch), where each tensors is stacked.

        # TODO: Your code
        sample_size = min(len(self.data), batch_size)
        sample_probs = self.get_probabilities(alpha)
        sample_indices = random.choices(range(len(self.data)), k=batch_size, weights=sample_probs)

        selected_samples = [self.data[i] for i in sample_indices]
        output = [torch.stack(b) for b in zip(*selected_samples)]
        importance = self.get_importance(sample_probs[sample_indices], beta)
        return output, sample_indices, importance

  """
# Out:
# '\nclass PrioritizedReplayBuffer:\n    def __init__(self, max_size: int):\n\n        #Create the replay buffer.\n\n        #:param max_size: Maximum number of transitions in the buffer.\n\n        self.data = []\n        self.priorities = []\n        self.max_size = max_size\n        self.position = 0\n\n    def __len__(self) -> int:\n        # Returns how many transitions are currently in the buffer\n        # TODO: Your code\n        return len(self.data)\n\n    def get_probabilities(self, alpha):\n        # Probability(i) = (priority(i)^alpha)/(Sum(priority(i)^alpha))\n        # Priority could have approximation errors, so to address this we use alpha;\n        # alpha=0.0 becomes Pure Random sampling\n        # alpha=1.0 becomes Pure prioritized random sampling\n        scaled_priorities = torch.pow(torch.tensor(self.priorities), alpha) #torch.tensor(self.priorities) ** alpha\n        probabilities = scaled_priorities/torch.sum(scaled_priorities)\n        return probabilities\n\n    def set_priorities(self, indices, errors, offset=0.05):\n        for i, e in zip(indices, errors):\n            self.priorities[i] = abs(e) + offset\n\n    def get_importance(self, probabilities, beta):\n        # importance_weight = Corrects the bias introduced by not uniformly sampling during the neural network backward pass\n        # importance_weight = ((1/N) * (1/Probability(i))) ^ Beta\n        # Beta is a hyperparameter here; which similar to alpha, controls how much we want to prioritize\n        N_length = len(self.data)\n        importance_weight = (1/N_length * 1/probabilities)  #(1/len(self.data) * 1/probabilities) ** beta\n        scaled_importance_weight = torch.pow(importance_weight,beta)\n        importance_weight_normalized = scaled_importance_weight / torch.max(scaled_importance_weight)\n        return importance_weight_normalized\n\n    def store(self, obs: torch.Tensor, action: torch.Tensor, reward: torch.Tensor, next_obs: torch.Tensor, terminated: torch.Tensor):\n\n        #Adds a new transition to the buffer. When the buffer is full, overwrite the oldest transition.\n\n        #:param obs: The current observation.\n        #:param action: The action.\n        #:param reward: The reward.\n        #:param next_obs: The next observation.\n        #:param terminated: Whether the episode terminated.\n\n        # TODO: Your code\n        data = (obs, action, reward, next_obs, terminated)\n        if len(self.data) < self.max_size:\n            self.data.append(data)\n            self.priorities.append(max(self.priorities, default=1)) #Setting initial priorities\n        else:\n            self.position = self.position % self.max_size\n            self.data[self.position] = data\n            self.priorities[self.position] = max(self.priorities, default=1) #Setting initial priorities\n        self.position = self.position + 1\n\n    def sample(self, batch_size: int, alpha=1.0, beta=1.0) -> torch.Tensor:\n\n        #Sample a batch of transitions uniformly and with replacement. The respective elements e.g. states, actions, rewards etc. are stacked\n\n        #:param batch_size: The batch size.\n        #:returns: A tuple of tensors (obs_batch, action_batch, reward_batch, next_obs_batch, terminated_batch), where each tensors is stacked.\n\n        # TODO: Your code\n        sample_size = min(len(self.data), batch_size)\n        sample_probs = self.get_probabilities(alpha)\n        sample_indices = random.choices(range(len(self.data)), k=batch_size, weights=sample_probs)\n\n        selected_samples = [self.data[i] for i in sample_indices]\n        output = [torch.stack(b) for b in zip(*selected_samples)]\n        importance = self.get_importance(sample_probs[sample_indices], beta)\n        return output, sample_indices, importance\n\n  '

# %%
def update_dqn(
        q: nn.Module,
        q_target: nn.Module,
        optimizer: optim.Optimizer,
        gamma: float,
        obs: torch.Tensor,
        act: torch.Tensor,
        rew: torch.Tensor,
        next_obs: torch.Tensor,
        tm: torch.Tensor,
        importance_weights: torch.Tensor,
    ):
    """
    Update the DQN network for one optimizer step.

    :param q: The DQN network.
    :param q_target: The target DQN network.
    :param optimizer: The optimizer.
    :param gamma: The discount factor.
    :param obs: Batch of current observations.
    :param act: Batch of actions.
    :param rew: Batch of rewards.
    :param next_obs: Batch of next observations.
    :param tm: Batch of termination flags.

    """
    # TODO: Zero out the gradient
    optimizer.zero_grad()

    with torch.no_grad():
        next_q_from_qmodel = q(next_obs)
        next_q_state_from_target = q_target(next_obs)

        max_val = torch.max(next_q_from_qmodel, 1)[1]
        q_val_target = next_q_state_from_target.gather(1, max_val.unsqueeze(1))
        td_target = rew.unsqueeze(1) + gamma * q_val_target * (1 - tm.float().unsqueeze(1))

        # DQN Targets
        #q_val_target = q_target(next_obs).max(dim=1)[0]
        #td_target = rew + gamma * q_val_target * (1 - tm.float())
    q_val = q(obs).gather(1, act.unsqueeze(1))

    mseloss = F.mse_loss(q_val, td_target)
    importance_weights_mean = importance_weights.mean() #torch.FloatTensor(importance_weights).mean()
    weighted_loss = mseloss * importance_weights_mean #Assuming errors for individual samples in loss

    weighted_loss.backward()
    optimizer.step()

    error_batch =  torch.sub(q_val, td_target)
    error_batch = error_batch.detach()
    #error_batch = error_batch.half()
    error_batch = error_batch.byte()
    #print(f"UPDATE_DQN: type(error_batch[0])={type(error_batch[0])}, (error_batch[0]).dtype={(error_batch[0]).dtype}")

    return error_batch

# %%
EpisodeStats = namedtuple("Stats", ["episode_lengths", "episode_rewards"])


class DQNAgent:
    def __init__(self,
            env,
            gamma=0.99,
            lr=0.001,
            batch_size=64,
            eps_start=1.0,
            eps_end=0.1,
            schedule_duration=10_000,
            update_freq=100,
            maxlen=100_000,
            alpha=1.0,
            beta=1.0,
            buffer_hyperparam_eps_start = 1.0,
            buffer_hyperparam_eps_end = 0.1,
        ):
        """
        Initialize the DQN agent.

        :param env: The environment.
        :param gamma: The discount factor.
        :param lr: The learning rate.
        :param batch_size: Mini batch size.
        :param eps_start: The initial epsilon value.
        :param eps_end: The final epsilon value.
        :param schedule_duration: The duration of the schedule (in timesteps).
        :param update_freq: How often to update the Q target.
        :param max_size: Maximum number of transitions in the buffer.
        """

        self.env = env
        self.gamma = gamma
        self.batch_size = batch_size
        self.eps_start = eps_start
        self.eps_end = eps_end
        self.schedule_duration = schedule_duration
        self.update_freq = update_freq
        self.alpha = alpha
        self.beta = beta
        self.buffer_param_start = buffer_hyperparam_eps_start
        self.buffer_param_end = buffer_hyperparam_eps_end

        #self.error_to_set_priority = 0.0

        # TODO: Initialize the Prioritized Replay Buffer
        self.buffer = PrioritizedReplayBuffer(maxlen)

        # TODO: Initialize the Deep Q Network. Hint: Remember observation_space and action_space
        self.q = DQN(env.observation_space.shape, env.action_space.n)

        # TODO: Initialize the second Q Network, the target network. Load the parameters of the first one into the second
        self.q_target = DQN(env.observation_space.shape, env.action_space.n)
        self.q_target.load_state_dict(self.q.state_dict())

        # TODO: Create an ADAM optimizer for the Q network
        self.optimizer = optim.Adam(self.q.parameters(), lr=lr)

        self.policy = make_epsilon_greedy_policy(self.q, env.action_space.n)

        # Model trained only for q model (One network), q_target network just do load_state_dict of trained model
        for params in self.q_target.parameters():
            params.requires_grad = False


    def train(self, num_episodes: int) -> EpisodeStats:
        """
        Train the DQN agent.

        :param num_episodes: Number of episodes to train.
        :returns: The episode statistics.
        """
        # Keeps track of useful statistics
        stats = EpisodeStats(
            episode_lengths=np.zeros(num_episodes),
            episode_rewards=np.zeros(num_episodes),
        )
        current_timestep = 0

        epsilon = self.eps_start
        alpha = self.alpha
        beta = self.beta

        for i_episode in range(num_episodes):
            # Print out which episode we're on, useful for debugging.
            if (i_episode + 1) % 1 == 0:
                print(f'Episode {i_episode + 1} of {num_episodes}  Time Step: {current_timestep}  Epsilon: {epsilon:.3f} Alpha: {alpha:.3f} Beta: {beta:.3f}')

            # Reset the environment and get initial observation
            obs, _ = self.env.reset()

            for episode_time in itertools.count():
                #print(f"\n\n LOOP episode_time={episode_time}")

                # TODO: Get current epsilon value
                epsilon = linear_epsilon_decay(self.eps_start, self.eps_end, current_timestep, self.schedule_duration)
                alpha = self.alpha #linear_epsilon_decay(self.buffer_param_start, self.buffer_param_end, current_timestep, self.schedule_duration)
                beta = self.beta #linear_epsilon_decay(self.buffer_param_start, self.buffer_param_end, current_timestep, self.schedule_duration)

                # Choose action and execute
                action = self.policy(torch.as_tensor(obs).unsqueeze(0).float(), epsilon=epsilon)
                next_obs, reward, terminated, truncated, _ = self.env.step(action)

                # Update statistics
                stats.episode_rewards[i_episode] += reward
                stats.episode_lengths[i_episode] += 1

                # TODO: Store sample in the replay buffer
                self.buffer.store(
                    torch.as_tensor(obs, dtype=torch.float32),
                    torch.as_tensor(action),
                    torch.as_tensor(reward, dtype=torch.float32),
                    torch.as_tensor(next_obs, dtype=torch.float32),
                    torch.as_tensor(int(terminated))
                )

                # TODO: Sample a mini batch from the replay buffer
                data, sample_indices, importance = self.buffer.sample(self.batch_size, alpha, beta)
                obs_batch, act_batch, rew_batch, next_obs_batch, tm_batch = data
                #print(f"act_batch={act_batch}")

                # Update the Q network
                batch_errors = update_dqn(
                    self.q,
                    self.q_target,
                    self.optimizer,
                    self.gamma,
                    obs_batch.float(),
                    act_batch,
                    rew_batch.float(),
                    next_obs_batch.float(),
                    tm_batch,
                    importance
                )

                # Set prirority of experience based on errors returned from Update step
                self.buffer.set_priorities(sample_indices, batch_errors)

                # Update the current Q target
                if current_timestep % self.update_freq == 0:
                    self.q_target.load_state_dict(self.q.state_dict())
                current_timestep += 1

                #print(f"G-Set next_obs to obs to continue further")
                # Check whether the episode is finished
                if terminated or truncated or episode_time >= 500:
                    break
                obs = next_obs
        return stats

# %%
# Choose your environment
#env = gym.make('MinAtar/Breakout-v1', render_mode="rgb_array")
env = gym.make('MinAtar/SpaceInvaders-v1', render_mode="rgb_array")
# Print observation and action space infos
print(f"Training on {env.spec.id}")
print(f"Observation space: {env.observation_space}")
print(f"Action space: {env.action_space}\n")

# Hyperparameters, Hint: Change as you see fit

LR = 0.001
BATCH_SIZE = 8
REPLAY_BUFFER_SIZE = 100_000
UPDATE_FREQ = 100
EPS_START = 0.5
EPS_END = 0.05
SCHEDULE_DURATION = 15_000
NUM_EPISODES = 300 #1_000
DISCOUNT_FACTOR = 0.99

# Priority Scaling Hyperparameter
ALPHA = 1.0 #0.5
# Importance Sampling weight hyperparameter
BETA = 1.0 #0.5
# Try Decaying Hyperparamteres of Prioritizied Replay Buffer, since we need higher values during start of training and it learns
ALPHA_BETA_EPS_START = 1.0
ALPHA_BETA_EPS_END = 0.1

# Train DQN
agent = DQNAgent(
    env,
    gamma=DISCOUNT_FACTOR,
    lr=LR,
    batch_size=BATCH_SIZE,
    eps_start=EPS_START,
    eps_end=EPS_END,
    schedule_duration=SCHEDULE_DURATION,
    update_freq=UPDATE_FREQ,
    maxlen=REPLAY_BUFFER_SIZE,
    alpha=ALPHA,
    beta=BETA,
    buffer_hyperparam_eps_start = ALPHA_BETA_EPS_START,
    buffer_hyperparam_eps_end = ALPHA_BETA_EPS_END,
)
stats = agent.train(NUM_EPISODES)
# Out:
# Training on MinAtar/SpaceInvaders-v1
# Observation space: Box(False, True, (10, 10, 6), bool)
# Action space: Discrete(4)
#
# Episode 1 of 300  Time Step: 0  Epsilon: 0.500 Alpha: 1.000 Beta: 1.000
# Episode 2 of 300  Time Step: 66  Epsilon: 0.498 Alpha: 1.000 Beta: 1.000
# Episode 3 of 300  Time Step: 133  Epsilon: 0.496 Alpha: 1.000 Beta: 1.000
# Episode 4 of 300  Time Step: 231  Epsilon: 0.493 Alpha: 1.000 Beta: 1.000
# Episode 5 of 300  Time Step: 386  Epsilon: 0.488 Alpha: 1.000 Beta: 1.000
# Episode 6 of 300  Time Step: 452  Epsilon: 0.486 Alpha: 1.000 Beta: 1.000
# Episode 7 of 300  Time Step: 518  Epsilon: 0.484 Alpha: 1.000 Beta: 1.000
# Episode 8 of 300  Time Step: 545  Epsilon: 0.484 Alpha: 1.000 Beta: 1.000
# Episode 9 of 300  Time Step: 582  Epsilon: 0.483 Alpha: 1.000 Beta: 1.000
# Episode 10 of 300  Time Step: 620  Epsilon: 0.481 Alpha: 1.000 Beta: 1.000
# Episode 11 of 300  Time Step: 677  Epsilon: 0.480 Alpha: 1.000 Beta: 1.000
# Episode 12 of 300  Time Step: 705  Epsilon: 0.479 Alpha: 1.000 Beta: 1.000
# Episode 13 of 300  Time Step: 762  Epsilon: 0.477 Alpha: 1.000 Beta: 1.000
# Episode 14 of 300  Time Step: 800  Epsilon: 0.476 Alpha: 1.000 Beta: 1.000
# Episode 15 of 300  Time Step: 817  Epsilon: 0.476 Alpha: 1.000 Beta: 1.000
# Episode 16 of 300  Time Step: 864  Epsilon: 0.474 Alpha: 1.000 Beta: 1.000
# Episode 17 of 300  Time Step: 912  Epsilon: 0.473 Alpha: 1.000 Beta: 1.000
# Episode 18 of 300  Time Step: 930  Epsilon: 0.472 Alpha: 1.000 Beta: 1.000
# Episode 19 of 300  Time Step: 967  Epsilon: 0.471 Alpha: 1.000 Beta: 1.000
# Episode 20 of 300  Time Step: 1004  Epsilon: 0.470 Alpha: 1.000 Beta: 1.000
# Episode 21 of 300  Time Step: 1031  Epsilon: 0.469 Alpha: 1.000 Beta: 1.000
# Episode 22 of 300  Time Step: 1120  Epsilon: 0.466 Alpha: 1.000 Beta: 1.000
# Episode 23 of 300  Time Step: 1186  Epsilon: 0.464 Alpha: 1.000 Beta: 1.000
# Episode 24 of 300  Time Step: 1292  Epsilon: 0.461 Alpha: 1.000 Beta: 1.000
# Episode 25 of 300  Time Step: 1418  Epsilon: 0.457 Alpha: 1.000 Beta: 1.000
# Episode 26 of 300  Time Step: 1435  Epsilon: 0.457 Alpha: 1.000 Beta: 1.000
# Episode 27 of 300  Time Step: 1550  Epsilon: 0.454 Alpha: 1.000 Beta: 1.000
# Episode 28 of 300  Time Step: 1646  Epsilon: 0.451 Alpha: 1.000 Beta: 1.000
# Episode 29 of 300  Time Step: 1692  Epsilon: 0.449 Alpha: 1.000 Beta: 1.000
# Episode 30 of 300  Time Step: 1719  Epsilon: 0.448 Alpha: 1.000 Beta: 1.000
# Episode 31 of 300  Time Step: 1757  Epsilon: 0.447 Alpha: 1.000 Beta: 1.000
# Episode 32 of 300  Time Step: 1833  Epsilon: 0.445 Alpha: 1.000 Beta: 1.000
# Episode 33 of 300  Time Step: 1997  Epsilon: 0.440 Alpha: 1.000 Beta: 1.000
# Episode 34 of 300  Time Step: 2014  Epsilon: 0.440 Alpha: 1.000 Beta: 1.000
# Episode 35 of 300  Time Step: 2060  Epsilon: 0.438 Alpha: 1.000 Beta: 1.000
# Episode 36 of 300  Time Step: 2117  Epsilon: 0.437 Alpha: 1.000 Beta: 1.000
# Episode 37 of 300  Time Step: 2154  Epsilon: 0.435 Alpha: 1.000 Beta: 1.000
# Episode 38 of 300  Time Step: 2281  Epsilon: 0.432 Alpha: 1.000 Beta: 1.000
# Episode 39 of 300  Time Step: 2318  Epsilon: 0.430 Alpha: 1.000 Beta: 1.000
# Episode 40 of 300  Time Step: 2376  Epsilon: 0.429 Alpha: 1.000 Beta: 1.000
# Episode 41 of 300  Time Step: 2413  Epsilon: 0.428 Alpha: 1.000 Beta: 1.000
# Episode 42 of 300  Time Step: 2431  Epsilon: 0.427 Alpha: 1.000 Beta: 1.000
# Episode 43 of 300  Time Step: 2478  Epsilon: 0.426 Alpha: 1.000 Beta: 1.000
# Episode 44 of 300  Time Step: 2576  Epsilon: 0.423 Alpha: 1.000 Beta: 1.000
# Episode 45 of 300  Time Step: 2613  Epsilon: 0.422 Alpha: 1.000 Beta: 1.000
# Episode 46 of 300  Time Step: 2630  Epsilon: 0.421 Alpha: 1.000 Beta: 1.000
# Episode 47 of 300  Time Step: 2668  Epsilon: 0.420 Alpha: 1.000 Beta: 1.000
# Episode 48 of 300  Time Step: 2734  Epsilon: 0.418 Alpha: 1.000 Beta: 1.000
# Episode 49 of 300  Time Step: 2949  Epsilon: 0.412 Alpha: 1.000 Beta: 1.000
# Episode 50 of 300  Time Step: 2976  Epsilon: 0.411 Alpha: 1.000 Beta: 1.000
# Episode 51 of 300  Time Step: 3043  Epsilon: 0.409 Alpha: 1.000 Beta: 1.000
# Episode 52 of 300  Time Step: 3090  Epsilon: 0.407 Alpha: 1.000 Beta: 1.000
# Episode 53 of 300  Time Step: 3137  Epsilon: 0.406 Alpha: 1.000 Beta: 1.000
# Episode 54 of 300  Time Step: 3164  Epsilon: 0.405 Alpha: 1.000 Beta: 1.000
# Episode 55 of 300  Time Step: 3310  Epsilon: 0.401 Alpha: 1.000 Beta: 1.000
# Episode 56 of 300  Time Step: 3327  Epsilon: 0.400 Alpha: 1.000 Beta: 1.000
# Episode 57 of 300  Time Step: 3355  Epsilon: 0.399 Alpha: 1.000 Beta: 1.000
# Episode 58 of 300  Time Step: 3423  Epsilon: 0.397 Alpha: 1.000 Beta: 1.000
# Episode 59 of 300  Time Step: 3440  Epsilon: 0.397 Alpha: 1.000 Beta: 1.000
# Episode 60 of 300  Time Step: 3548  Epsilon: 0.394 Alpha: 1.000 Beta: 1.000
# Episode 61 of 300  Time Step: 3624  Epsilon: 0.391 Alpha: 1.000 Beta: 1.000
# Episode 62 of 300  Time Step: 3652  Epsilon: 0.390 Alpha: 1.000 Beta: 1.000
# Episode 63 of 300  Time Step: 3679  Epsilon: 0.390 Alpha: 1.000 Beta: 1.000
# Episode 64 of 300  Time Step: 3696  Epsilon: 0.389 Alpha: 1.000 Beta: 1.000
# Episode 65 of 300  Time Step: 3733  Epsilon: 0.388 Alpha: 1.000 Beta: 1.000
# Episode 66 of 300  Time Step: 3760  Epsilon: 0.387 Alpha: 1.000 Beta: 1.000
# Episode 67 of 300  Time Step: 3828  Epsilon: 0.385 Alpha: 1.000 Beta: 1.000
# Episode 68 of 300  Time Step: 3944  Epsilon: 0.382 Alpha: 1.000 Beta: 1.000
# Episode 69 of 300  Time Step: 3971  Epsilon: 0.381 Alpha: 1.000 Beta: 1.000
# Episode 70 of 300  Time Step: 4008  Epsilon: 0.380 Alpha: 1.000 Beta: 1.000
# Episode 71 of 300  Time Step: 4026  Epsilon: 0.379 Alpha: 1.000 Beta: 1.000
# Episode 72 of 300  Time Step: 4064  Epsilon: 0.378 Alpha: 1.000 Beta: 1.000
# Episode 73 of 300  Time Step: 4091  Epsilon: 0.377 Alpha: 1.000 Beta: 1.000
# Episode 74 of 300  Time Step: 4138  Epsilon: 0.376 Alpha: 1.000 Beta: 1.000
# Episode 75 of 300  Time Step: 4206  Epsilon: 0.374 Alpha: 1.000 Beta: 1.000
# Episode 76 of 300  Time Step: 4293  Epsilon: 0.371 Alpha: 1.000 Beta: 1.000
# Episode 77 of 300  Time Step: 4331  Epsilon: 0.370 Alpha: 1.000 Beta: 1.000
# Episode 78 of 300  Time Step: 4417  Epsilon: 0.368 Alpha: 1.000 Beta: 1.000
# Episode 79 of 300  Time Step: 4515  Epsilon: 0.365 Alpha: 1.000 Beta: 1.000
# Episode 80 of 300  Time Step: 4571  Epsilon: 0.363 Alpha: 1.000 Beta: 1.000
# Episode 81 of 300  Time Step: 4588  Epsilon: 0.362 Alpha: 1.000 Beta: 1.000
# Episode 82 of 300  Time Step: 4634  Epsilon: 0.361 Alpha: 1.000 Beta: 1.000
# Episode 83 of 300  Time Step: 4672  Epsilon: 0.360 Alpha: 1.000 Beta: 1.000
# Episode 84 of 300  Time Step: 4689  Epsilon: 0.359 Alpha: 1.000 Beta: 1.000
# Episode 85 of 300  Time Step: 4706  Epsilon: 0.359 Alpha: 1.000 Beta: 1.000
# Episode 86 of 300  Time Step: 4881  Epsilon: 0.354 Alpha: 1.000 Beta: 1.000
# Episode 87 of 300  Time Step: 4937  Epsilon: 0.352 Alpha: 1.000 Beta: 1.000
# Episode 88 of 300  Time Step: 4975  Epsilon: 0.351 Alpha: 1.000 Beta: 1.000
# Episode 89 of 300  Time Step: 5112  Epsilon: 0.347 Alpha: 1.000 Beta: 1.000
# Episode 90 of 300  Time Step: 5139  Epsilon: 0.346 Alpha: 1.000 Beta: 1.000
# Episode 91 of 300  Time Step: 5176  Epsilon: 0.345 Alpha: 1.000 Beta: 1.000
# Episode 92 of 300  Time Step: 5243  Epsilon: 0.343 Alpha: 1.000 Beta: 1.000
# Episode 93 of 300  Time Step: 5301  Epsilon: 0.341 Alpha: 1.000 Beta: 1.000
# Episode 94 of 300  Time Step: 5347  Epsilon: 0.340 Alpha: 1.000 Beta: 1.000
# Episode 95 of 300  Time Step: 5376  Epsilon: 0.339 Alpha: 1.000 Beta: 1.000
# Episode 96 of 300  Time Step: 5393  Epsilon: 0.338 Alpha: 1.000 Beta: 1.000
# Episode 97 of 300  Time Step: 5439  Epsilon: 0.337 Alpha: 1.000 Beta: 1.000
# Episode 98 of 300  Time Step: 5467  Epsilon: 0.336 Alpha: 1.000 Beta: 1.000
# Episode 99 of 300  Time Step: 5484  Epsilon: 0.336 Alpha: 1.000 Beta: 1.000
# Episode 100 of 300  Time Step: 5523  Epsilon: 0.334 Alpha: 1.000 Beta: 1.000
# Episode 101 of 300  Time Step: 5590  Epsilon: 0.332 Alpha: 1.000 Beta: 1.000
# Episode 102 of 300  Time Step: 5765  Epsilon: 0.327 Alpha: 1.000 Beta: 1.000
# Episode 103 of 300  Time Step: 5861  Epsilon: 0.324 Alpha: 1.000 Beta: 1.000
# Episode 104 of 300  Time Step: 5900  Epsilon: 0.323 Alpha: 1.000 Beta: 1.000
# Episode 105 of 300  Time Step: 5957  Epsilon: 0.321 Alpha: 1.000 Beta: 1.000
# Episode 106 of 300  Time Step: 6003  Epsilon: 0.320 Alpha: 1.000 Beta: 1.000
# Episode 107 of 300  Time Step: 6020  Epsilon: 0.319 Alpha: 1.000 Beta: 1.000
# Episode 108 of 300  Time Step: 6088  Epsilon: 0.317 Alpha: 1.000 Beta: 1.000
# Episode 109 of 300  Time Step: 6186  Epsilon: 0.314 Alpha: 1.000 Beta: 1.000
# Episode 110 of 300  Time Step: 6214  Epsilon: 0.314 Alpha: 1.000 Beta: 1.000
# Episode 111 of 300  Time Step: 6260  Epsilon: 0.312 Alpha: 1.000 Beta: 1.000
# Episode 112 of 300  Time Step: 6406  Epsilon: 0.308 Alpha: 1.000 Beta: 1.000
# Episode 113 of 300  Time Step: 6423  Epsilon: 0.307 Alpha: 1.000 Beta: 1.000
# Episode 114 of 300  Time Step: 6607  Epsilon: 0.302 Alpha: 1.000 Beta: 1.000
# Episode 115 of 300  Time Step: 6635  Epsilon: 0.301 Alpha: 1.000 Beta: 1.000
# Episode 116 of 300  Time Step: 6731  Epsilon: 0.298 Alpha: 1.000 Beta: 1.000
# Episode 117 of 300  Time Step: 6977  Epsilon: 0.291 Alpha: 1.000 Beta: 1.000
# Episode 118 of 300  Time Step: 6994  Epsilon: 0.290 Alpha: 1.000 Beta: 1.000
# Episode 119 of 300  Time Step: 7011  Epsilon: 0.290 Alpha: 1.000 Beta: 1.000
# Episode 120 of 300  Time Step: 7057  Epsilon: 0.288 Alpha: 1.000 Beta: 1.000
# Episode 121 of 300  Time Step: 7184  Epsilon: 0.285 Alpha: 1.000 Beta: 1.000
# Episode 122 of 300  Time Step: 7230  Epsilon: 0.283 Alpha: 1.000 Beta: 1.000
# Episode 123 of 300  Time Step: 7346  Epsilon: 0.280 Alpha: 1.000 Beta: 1.000
# Episode 124 of 300  Time Step: 7373  Epsilon: 0.279 Alpha: 1.000 Beta: 1.000
# Episode 125 of 300  Time Step: 7459  Epsilon: 0.276 Alpha: 1.000 Beta: 1.000
# Episode 126 of 300  Time Step: 7607  Epsilon: 0.272 Alpha: 1.000 Beta: 1.000
# Episode 127 of 300  Time Step: 7784  Epsilon: 0.267 Alpha: 1.000 Beta: 1.000
# Episode 128 of 300  Time Step: 7883  Epsilon: 0.264 Alpha: 1.000 Beta: 1.000
# Episode 129 of 300  Time Step: 7998  Epsilon: 0.260 Alpha: 1.000 Beta: 1.000
# Episode 130 of 300  Time Step: 8015  Epsilon: 0.260 Alpha: 1.000 Beta: 1.000
# Episode 131 of 300  Time Step: 8162  Epsilon: 0.255 Alpha: 1.000 Beta: 1.000
# Episode 132 of 300  Time Step: 8249  Epsilon: 0.253 Alpha: 1.000 Beta: 1.000
# Episode 133 of 300  Time Step: 8307  Epsilon: 0.251 Alpha: 1.000 Beta: 1.000
# Episode 134 of 300  Time Step: 8334  Epsilon: 0.250 Alpha: 1.000 Beta: 1.000
# Episode 135 of 300  Time Step: 8459  Epsilon: 0.246 Alpha: 1.000 Beta: 1.000
# Episode 136 of 300  Time Step: 8546  Epsilon: 0.244 Alpha: 1.000 Beta: 1.000
# Episode 137 of 300  Time Step: 8731  Epsilon: 0.238 Alpha: 1.000 Beta: 1.000
# Episode 138 of 300  Time Step: 8945  Epsilon: 0.232 Alpha: 1.000 Beta: 1.000
# Episode 139 of 300  Time Step: 9101  Epsilon: 0.227 Alpha: 1.000 Beta: 1.000
# Episode 140 of 300  Time Step: 9147  Epsilon: 0.226 Alpha: 1.000 Beta: 1.000
# Episode 141 of 300  Time Step: 9265  Epsilon: 0.222 Alpha: 1.000 Beta: 1.000
# Episode 142 of 300  Time Step: 9303  Epsilon: 0.221 Alpha: 1.000 Beta: 1.000
# Episode 143 of 300  Time Step: 9560  Epsilon: 0.213 Alpha: 1.000 Beta: 1.000
# Episode 144 of 300  Time Step: 9588  Epsilon: 0.212 Alpha: 1.000 Beta: 1.000
# Episode 145 of 300  Time Step: 9755  Epsilon: 0.207 Alpha: 1.000 Beta: 1.000
# Episode 146 of 300  Time Step: 9792  Epsilon: 0.206 Alpha: 1.000 Beta: 1.000
# Episode 147 of 300  Time Step: 9908  Epsilon: 0.203 Alpha: 1.000 Beta: 1.000
# Episode 148 of 300  Time Step: 9984  Epsilon: 0.201 Alpha: 1.000 Beta: 1.000
# Episode 149 of 300  Time Step: 10070  Epsilon: 0.198 Alpha: 1.000 Beta: 1.000
# Episode 150 of 300  Time Step: 10216  Epsilon: 0.194 Alpha: 1.000 Beta: 1.000
# Episode 151 of 300  Time Step: 10534  Epsilon: 0.184 Alpha: 1.000 Beta: 1.000
# Episode 152 of 300  Time Step: 10698  Epsilon: 0.179 Alpha: 1.000 Beta: 1.000
# Episode 153 of 300  Time Step: 10754  Epsilon: 0.177 Alpha: 1.000 Beta: 1.000
# Episode 154 of 300  Time Step: 10771  Epsilon: 0.177 Alpha: 1.000 Beta: 1.000
# Episode 155 of 300  Time Step: 10947  Epsilon: 0.172 Alpha: 1.000 Beta: 1.000
# Episode 156 of 300  Time Step: 11023  Epsilon: 0.169 Alpha: 1.000 Beta: 1.000
# Episode 157 of 300  Time Step: 11308  Epsilon: 0.161 Alpha: 1.000 Beta: 1.000
# Episode 158 of 300  Time Step: 11706  Epsilon: 0.149 Alpha: 1.000 Beta: 1.000
# Episode 159 of 300  Time Step: 11853  Epsilon: 0.144 Alpha: 1.000 Beta: 1.000
# Episode 160 of 300  Time Step: 11892  Epsilon: 0.143 Alpha: 1.000 Beta: 1.000
# Episode 161 of 300  Time Step: 12057  Epsilon: 0.138 Alpha: 1.000 Beta: 1.000
# Episode 162 of 300  Time Step: 12241  Epsilon: 0.133 Alpha: 1.000 Beta: 1.000
# Episode 163 of 300  Time Step: 12602  Epsilon: 0.122 Alpha: 1.000 Beta: 1.000
# Episode 164 of 300  Time Step: 12648  Epsilon: 0.121 Alpha: 1.000 Beta: 1.000
# Episode 165 of 300  Time Step: 12923  Epsilon: 0.112 Alpha: 1.000 Beta: 1.000
# Episode 166 of 300  Time Step: 12971  Epsilon: 0.111 Alpha: 1.000 Beta: 1.000
# Episode 167 of 300  Time Step: 12988  Epsilon: 0.110 Alpha: 1.000 Beta: 1.000
# Episode 168 of 300  Time Step: 13193  Epsilon: 0.104 Alpha: 1.000 Beta: 1.000
# Episode 169 of 300  Time Step: 13232  Epsilon: 0.103 Alpha: 1.000 Beta: 1.000
# Episode 170 of 300  Time Step: 13695  Epsilon: 0.089 Alpha: 1.000 Beta: 1.000
# Episode 171 of 300  Time Step: 13800  Epsilon: 0.086 Alpha: 1.000 Beta: 1.000
# Episode 172 of 300  Time Step: 13857  Epsilon: 0.084 Alpha: 1.000 Beta: 1.000
# Episode 173 of 300  Time Step: 13963  Epsilon: 0.081 Alpha: 1.000 Beta: 1.000
# Episode 174 of 300  Time Step: 14020  Epsilon: 0.079 Alpha: 1.000 Beta: 1.000
# Episode 175 of 300  Time Step: 14106  Epsilon: 0.077 Alpha: 1.000 Beta: 1.000
# Episode 176 of 300  Time Step: 14213  Epsilon: 0.074 Alpha: 1.000 Beta: 1.000
# Episode 177 of 300  Time Step: 14598  Epsilon: 0.062 Alpha: 1.000 Beta: 1.000
# Episode 178 of 300  Time Step: 14635  Epsilon: 0.061 Alpha: 1.000 Beta: 1.000
# Episode 179 of 300  Time Step: 14672  Epsilon: 0.060 Alpha: 1.000 Beta: 1.000
# Episode 180 of 300  Time Step: 14957  Epsilon: 0.051 Alpha: 1.000 Beta: 1.000
# Episode 181 of 300  Time Step: 15062  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 182 of 300  Time Step: 15217  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 183 of 300  Time Step: 15470  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 184 of 300  Time Step: 15556  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 185 of 300  Time Step: 15909  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 186 of 300  Time Step: 16075  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 187 of 300  Time Step: 16112  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 188 of 300  Time Step: 16415  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 189 of 300  Time Step: 16550  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 190 of 300  Time Step: 16647  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 191 of 300  Time Step: 16684  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 192 of 300  Time Step: 17129  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 193 of 300  Time Step: 17518  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 194 of 300  Time Step: 17654  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 195 of 300  Time Step: 17782  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 196 of 300  Time Step: 18065  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 197 of 300  Time Step: 18093  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 198 of 300  Time Step: 18432  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 199 of 300  Time Step: 18449  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 200 of 300  Time Step: 18787  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 201 of 300  Time Step: 18873  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 202 of 300  Time Step: 18960  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 203 of 300  Time Step: 19157  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 204 of 300  Time Step: 19441  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 205 of 300  Time Step: 19478  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 206 of 300  Time Step: 19623  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 207 of 300  Time Step: 19700  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 208 of 300  Time Step: 19917  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 209 of 300  Time Step: 19973  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 210 of 300  Time Step: 20128  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 211 of 300  Time Step: 20527  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 212 of 300  Time Step: 20919  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 213 of 300  Time Step: 21006  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 214 of 300  Time Step: 21104  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 215 of 300  Time Step: 21150  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 216 of 300  Time Step: 21604  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 217 of 300  Time Step: 22062  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 218 of 300  Time Step: 22403  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 219 of 300  Time Step: 22796  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 220 of 300  Time Step: 23059  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 221 of 300  Time Step: 23147  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 222 of 300  Time Step: 23252  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 223 of 300  Time Step: 23438  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 224 of 300  Time Step: 23555  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 225 of 300  Time Step: 23947  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 226 of 300  Time Step: 24131  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 227 of 300  Time Step: 24414  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 228 of 300  Time Step: 24579  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 229 of 300  Time Step: 24822  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 230 of 300  Time Step: 24909  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 231 of 300  Time Step: 24995  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 232 of 300  Time Step: 25092  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 233 of 300  Time Step: 25315  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 234 of 300  Time Step: 25332  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 235 of 300  Time Step: 25359  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 236 of 300  Time Step: 25457  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 237 of 300  Time Step: 25664  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 238 of 300  Time Step: 25937  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 239 of 300  Time Step: 26131  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 240 of 300  Time Step: 26148  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 241 of 300  Time Step: 26254  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 242 of 300  Time Step: 26350  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 243 of 300  Time Step: 26545  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 244 of 300  Time Step: 26602  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 245 of 300  Time Step: 26828  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 246 of 300  Time Step: 26845  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 247 of 300  Time Step: 26950  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 248 of 300  Time Step: 27154  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 249 of 300  Time Step: 27331  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 250 of 300  Time Step: 27604  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 251 of 300  Time Step: 27660  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 252 of 300  Time Step: 27717  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 253 of 300  Time Step: 27815  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 254 of 300  Time Step: 27911  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 255 of 300  Time Step: 28036  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 256 of 300  Time Step: 28230  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 257 of 300  Time Step: 28512  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 258 of 300  Time Step: 28608  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 259 of 300  Time Step: 28715  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 260 of 300  Time Step: 28761  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 261 of 300  Time Step: 28807  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 262 of 300  Time Step: 28904  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 263 of 300  Time Step: 29001  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 264 of 300  Time Step: 29097  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 265 of 300  Time Step: 29323  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 266 of 300  Time Step: 29708  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 267 of 300  Time Step: 30061  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 268 of 300  Time Step: 30186  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 269 of 300  Time Step: 30203  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 270 of 300  Time Step: 30220  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 271 of 300  Time Step: 30436  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 272 of 300  Time Step: 30574  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 273 of 300  Time Step: 30660  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 274 of 300  Time Step: 30875  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 275 of 300  Time Step: 30980  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 276 of 300  Time Step: 31204  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 277 of 300  Time Step: 31537  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 278 of 300  Time Step: 31642  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 279 of 300  Time Step: 31806  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 280 of 300  Time Step: 32039  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 281 of 300  Time Step: 32214  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 282 of 300  Time Step: 32398  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 283 of 300  Time Step: 32730  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 284 of 300  Time Step: 32914  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 285 of 300  Time Step: 32980  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 286 of 300  Time Step: 33195  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 287 of 300  Time Step: 33350  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 288 of 300  Time Step: 33574  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 289 of 300  Time Step: 33959  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 290 of 300  Time Step: 34084  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 291 of 300  Time Step: 34189  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 292 of 300  Time Step: 34255  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 293 of 300  Time Step: 34439  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 294 of 300  Time Step: 34604  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 295 of 300  Time Step: 34944  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 296 of 300  Time Step: 35158  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 297 of 300  Time Step: 35216  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 298 of 300  Time Step: 35351  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 299 of 300  Time Step: 35734  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000
# Episode 300 of 300  Time Step: 36040  Epsilon: 0.050 Alpha: 1.000 Beta: 1.000

# %% [markdown]
# # 1.5 Results
#
# Like in the last exercise, we will look at the resulting episode reward.

# %%
smoothing_window=20
fig, axes = plt.subplots(1, 2, figsize=(10, 5), tight_layout=True)

# Plot the episode length over time
ax = axes[0]
ax.plot(stats.episode_lengths)
ax.set_xlabel("Episode")
ax.set_ylabel("Episode Length")
ax.set_title("Episode Length over Time")

# Plot the episode reward over time
ax = axes[1]
rewards_smoothed = pd.Series(stats.episode_rewards).rolling(smoothing_window, min_periods=smoothing_window).mean()
ax.plot(rewards_smoothed)
ax.set_xlabel("Episode")
ax.set_ylabel("Episode Reward (Smoothed)")
ax.set_title(f"Episode Reward over Time\n(Smoothed over window size {smoothing_window})")
plt.show()

# %% [markdown]
# Lastly, let us see what the learned policy does in action.

# %%
from IPython.display import Image as IImage

def save_rgb_animation(rgb_arrays, filename, duration=50):
    """Save an animated GIF from a list of RGB arrays."""
    # Create a list to hold each frame
    frames = []

    # Convert RGB arrays to PIL Image objects
    for rgb_array in rgb_arrays:
        rgb_array = (rgb_array*255).astype(np.uint8)
        rgb_array = rgb_array.repeat(48, axis=0).repeat(48, axis=1)
        img = Image.fromarray(rgb_array)
        frames.append(img)

    # Save the frames as an animated GIF
    frames[0].save(filename, save_all=True, append_images=frames[1:], duration=duration, loop=0)

def rendered_rollout(policy, env, max_steps=1_000):
    """Rollout for one episode while saving all rendered images."""
    obs, _ = env.reset()
    imgs = [env.render()]

    for _ in range(max_steps):
        action = policy(torch.as_tensor(obs, dtype=torch.float32).unsqueeze(0))
        obs, _, terminated, truncated, _ = env.step(action)
        imgs.append(env.render())

        if terminated or truncated:
            break

    return imgs

policy = make_epsilon_greedy_policy(agent.q, num_actions=env.action_space.n)
imgs = rendered_rollout(policy, env)
save_rgb_animation(imgs, "trained.gif")
IImage(filename="trained.gif")
